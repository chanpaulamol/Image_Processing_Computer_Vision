# %% [markdown]
# <a href="https://colab.research.google.com/github/chanpaulamol/Image_Processing_Computer_Vision/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Access my drive

# %%
from google.colab import drive
# Mount drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Import Libraries

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
# Image path
image_path = '/content/drive/MyDrive/PCVK/facedet/jokowi.jpg'

# Read the images
jokowi = cv.imread(image_path)

# Load the face cascade classifier
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalface_alt.xml')

# Detect faces in the image
faces = face_cascade.detectMultiScale(jokowi)

# Draw rectangles around the detected faces
for (x, y, w, h) in faces:
    cv.rectangle(jokowi, (x, y), (x+w, y+h), (255, 0, 0), 3)

# Display the original image and the image with detected faces
plt.figure(figsize=(10, 5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(cv.cvtColor(cv.imread(image_path), cv.COLOR_BGR2RGB))
plt.title('Original')

# Image with detected faces
plt.subplot(1, 2, 2)
plt.imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
plt.title('Detected Faces')

plt.show()

# %%
# Image path
kartini_path = '/content/drive/MyDrive/PCVK/facedet/kartini.jpg'

# Read the image
kartini = cv.imread(kartini_path)

# Load the face cascade classifier
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalface_alt.xml')

# Detect faces in the kartini image
faces = face_cascade.detectMultiScale(kartini)

# Draw rectangles around the detected faces
for (x, y, w, h) in faces:
    cv.rectangle(kartini, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Display the original image and the image with detected faces
plt.figure(figsize=(10, 5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(cv.cvtColor(cv.imread(kartini_path), cv.COLOR_BGR2RGB))
plt.title('Original')

# Image with detected faces
plt.subplot(1, 2, 2)
plt.imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
plt.title('Detected Faces')

plt.show()

# %%
# Image path
kucing_path = '/content/drive/MyDrive/PCVK/facedet/kucing.jpg'

# Read the image
kucing = cv.imread(kucing_path)

# Convert the image to grayscale
gray = cv.cvtColor(kucing, cv.COLOR_BGR2GRAY)

# Load the face cascade classifier
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalface_alt.xml')

# Detect faces in the grayscale image
faces = face_cascade.detectMultiScale(gray)

# Draw rectangles around the detected faces
for (x, y, w, h) in faces:
    cv.rectangle(gray, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Display the original image and the image with detected faces
plt.figure(figsize=(10, 5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(cv.cvtColor(gray, cv.COLOR_BGR2RGB))
plt.title('Original')

# Image with detected faces
plt.subplot(1, 2, 2)
plt.imshow(cv.cvtColor(gray, cv.COLOR_BGR2RGB))
plt.title('Detected Faces')

plt.show()

# %%
# Image paths
mask_path = '/content/drive/MyDrive/PCVK/facedet/mask.png'

# Read the original image
mask = cv.imread(mask_path, 0)

# Load the face cascade classifier
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalface_alt.xml')

# Detect faces in the original image
mask_faces = face_cascade.detectMultiScale(mask)

# Draw rectangles around the detected faces in the original image
for (x, y, w, h) in mask_faces:
    cv.rectangle(mask, (x, y), (x+w, y+h), (255, 0, 255), 3)

# Display the original and modified images with detected faces
plt.figure(figsize=(10, 10))
f, axarr = plt.subplots(1, 2, figsize=(15, 5))

# Original image
gray_mask = cv.cvtColor(cv.imread(mask_path, 0), cv.COLOR_BGR2RGB)
plt.subplot(121)
plt.imshow(gray_mask, cmap='gray')
plt.title('Original')

# Modified image with detected faces
plt.subplot(122)
plt.imshow(mask, cmap='gray')
plt.title('Detected Faces')

plt.show()

# %%
# Image path
mjordan_path = '/content/drive/MyDrive/PCVK/facedet/mjordan.jpg'

# Read the original image
mjordan = cv.imread(mjordan_path, 0)

# Load the face cascade classifier
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalface_alt.xml')

# Detect faces in the grayscale image
mjordan_faces = face_cascade.detectMultiScale(mjordan)

# Draw rectangles around the detected faces in the grayscale image
for (x, y, w, h) in mjordan_faces:
    cv.rectangle(mjordan, (x, y), (x+w, y+h), (255, 0, 255), 3)

# Display the original and modified images with detected faces
plt.figure(figsize=(12, 6))

# Grayscale image with detected faces
plt.subplot(1, 2, 2)
plt.imshow(mjordan, cmap='gray')
plt.title('Detected Faces')

plt.tight_layout()
plt.show()

# %%
# Image path
solvayconf_path = '/content/drive/MyDrive/PCVK/facedet/solvayconf.jpg'

# Read the original image
solvayconf = cv.imread(solvayconf_path)

# Convert the image to grayscale
gray_solvayconf = cv.cvtColor(solvayconf, cv.COLOR_BGR2GRAY)

# Load the face cascade classifier
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalface_alt.xml')

# Detect faces in the grayscale image
faces = face_cascade.detectMultiScale(gray_solvayconf)

# Draw rectangles around the detected faces in the grayscale image
for (x, y, w, h) in faces:
    cv.rectangle(gray_solvayconf, (x, y), (x+w, y+h), (255, 0, 255), 3)

# Display the original image and the grayscale image with detected faces
plt.figure(figsize=(12, 6))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(cv.cvtColor(solvayconf, cv.COLOR_BGR2RGB))
plt.title('Original')

# Grayscale image with detected faces
plt.subplot(1, 2, 2)
plt.imshow(cv.cvtColor(gray_solvayconf, cv.COLOR_BGR2RGB), cmap='gray')
plt.title('Grayscale with Detected Faces')

plt.tight_layout()
plt.show()

# %%
# Load the cat face cascade classifier
cascade_cat = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalcatface.xml')

# Read the image
kucing = cv2.imread('/content/drive/MyDrive/PCVK/facedet/kucing.jpg')
kucing_gray = cv2.cvtColor(kucing, cv2.COLOR_BGR2GRAY)

# Detect cat faces in the image
roi_wajah = cascade_cat.detectMultiScale(kucing_gray)

# Draw rectangles around the detected cat faces
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(kucing_gray, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Display the original image and the image with detected faces
plt.figure(figsize=(10, 5))

# Image with detected faces
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(kucing_gray, cv2.COLOR_BGR2RGB))
plt.title('Detected Faces')

plt.show()

# %%
# Load the eye cascade classifier
eye_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_lefteye_2splits.xml')

# Read the image
jokowi = cv2.imread('/content/drive/MyDrive/PCVK/facedet/jokowi.jpg')
jokowi_gray = cv.cvtColor(jokowi, cv2.COLOR_BGR2GRAY)
jokowi_detected = jokowi_gray.copy()

# Detect eye regions in the image
eye_regions = eye_cascade.detectMultiScale(jokowi_gray)

# Draw rectangles around the detected eye regions
for (x, y, w, h) in eye_regions:
    cv.rectangle(jokowi_detected, (x, y), (x+w, y+h), (255, 255, 255), 3)

# Plot the original image and the image with detected eye regions
plt.figure(figsize=(10, 10))
f, axarr = plt.subplots(1, 2, figsize=(15, 5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(cv.cvtColor(jokowi_gray, cv.COLOR_BGR2RGB), cmap='gray')
plt.title('Original')

# Image with detected eye regions
plt.subplot(1, 2, 2)
plt.imshow(cv.cvtColor(jokowi_detected, cv.COLOR_BGR2RGB), cmap='gray')
plt.title('Detected Eye Regions')

plt.show()

# %%
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import PIL
import io
import cv2
import numpy as np

# Function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
    # Decode base64 image
    image_bytes = b64decode(js_reply.split(',')[1])
    # Convert bytes to numpy array
    image_np = np.frombuffer(image_bytes, dtype=np.uint8)
    # Decode numpy array into OpenCV BGR image
    img = cv2.imdecode(image_np, flags=1)
    return img

# Function to convert OpenCV image to base64 byte string
def image_to_base64(image):
    # Convert image to PIL format
    pil_image = PIL.Image.fromarray(image)
    # Create an in-memory buffer to hold the image
    image_buffer = io.BytesIO()
    # Save the PIL image as PNG to the buffer
    pil_image.save(image_buffer, format='PNG')
    # Get the byte data from the buffer
    byte_data = image_buffer.getvalue()
    # Encode the byte data as base64 string
    base64_str = b64encode(byte_data).decode('utf-8')
    return base64_str

# Function to convert OpenCV rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
    # Convert array into PIL image
    bbox_pil = PIL.Image.fromarray(bbox_array, 'RGBA')
    iobuf = io.BytesIO()
    # Format bbox into PNG for return
    bbox_pil.save(iobuf, format='png')
    # Format return string
    bbox_bytes = 'data:image/png;base64,{}'.format(str(b64encode(iobuf.getvalue()), 'utf-8'))
    return bbox_bytes

# Initialize the Haar Cascade face detection model
face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalface_default.xml')

def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
        async function takePhoto(quality) {
            const div = document.createElement('div');
            const capture = document.createElement('button');
            capture.textContent = 'Capture';
            div.appendChild(capture);

            const video = document.createElement('video');
            video.style.display = 'block';
            const stream = await navigator.mediaDevices.getUserMedia({ video: true });

            document.body.appendChild(div);
            div.appendChild(video);
            video.srcObject = stream;
            await video.play();

            // Resize the output to fit the video element.
            google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

            // Wait for Capture to be clicked.
            await new Promise((resolve) => capture.onclick = resolve);

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            canvas.getContext('2d').drawImage(video, 0, 0);
            stream.getVideoTracks()[0].stop();
            div.remove();
            return canvas.toDataURL('image/jpeg', quality);
        }
    ''')
    display(js)

    # Get photo data
    data = eval_js('takePhoto({})'.format(quality))
    # Get OpenCV format image
    img = js_to_image(data)
    # Convert image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    print(gray.shape)
    # Get face bounding box coordinates using Haar Cascade
    faces = face_cascade.detectMultiScale(gray)
    # Draw face bounding box on image
    for (x, y, w, h) in faces:
        img = cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    # Save image
    cv2.imwrite(filename, img)

    return filename

try:
    filename = take_photo('photo.jpg')
    print('Saved to {}'.format(filename))

    # Show the image which was just taken
    display(Image(filename))
except Exception as err:
    # Errors will be thrown if the user does not have a webcam or if they do not grant the page permission to access it
    print(str(err))

# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
    js = Javascript('''
        var video;
        var div = null;
        var stream;
        var captureCanvas;
        var imgElement;
        var labelElement;

        var pendingResolve = null;
        var shutdown = false;

        function removeDom() {
            stream.getVideoTracks()[0].stop();
            video.remove();
            div.remove();
            video = null;
            div = null;
            stream = null;
            imgElement = null;
            captureCanvas = null;
            labelElement = null;
        }

        function onAnimationFrame() {
            if (!shutdown) {
                window.requestAnimationFrame(onAnimationFrame);
            }
            if (pendingResolve) {
                var result = "";
                if (!shutdown) {
                    captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
                    result = captureCanvas.toDataURL('image/jpeg', 0.8);
                }
                var lp = pendingResolve;
                pendingResolve = null;
                lp(result);
            }
        }

        async function createDom() {
            if (div !== null) {
                return stream;
            }

            div = document.createElement('div');
            div.style.border = '2px solid black';
            div.style.padding = '3px';
            div.style.width = '100%';
            div.style.maxWidth = '600px';
            document.body.appendChild(div);

            const modelOut = document.createElement('div');
            modelOut.innerHTML = "<span>Status:</span>";
            labelElement = document.createElement('span');
            labelElement.innerText = 'No data';
            labelElement.style.fontWeight = 'bold';
            modelOut.appendChild(labelElement);
            div.appendChild(modelOut);

            video = document.createElement('video');
            video.style.display = 'block';
            video.width = div.clientWidth - 6;
            video.setAttribute('playsinline', '');
            video.onclick = () => { shutdown = true; };
            stream = await navigator.mediaDevices.getUserMedia({ video: { facingMode: "environment" } });
            div.appendChild(video);

            imgElement = document.createElement('img');
            imgElement.style.position = 'absolute';
            imgElement.style.zIndex = 1;
            imgElement.onclick = () => { shutdown = true; };
            div.appendChild(imgElement);

            const instruction = document.createElement('div');
            instruction.innerHTML =
                '<span style="color: red; font-weight: bold;">' +
                'When finished, click here or on the video to stop this demo</span>';
            div.appendChild(instruction);
            instruction.onclick = () => { shutdown = true; };

            video.srcObject = stream;
            await video.play();

            captureCanvas = document.createElement('canvas');
            captureCanvas.width = 640;
            captureCanvas.height = 480;
            window.requestAnimationFrame(onAnimationFrame);

            return stream;
        }

        async function stream_frame(label, imgData) {
            if (shutdown) {
                removeDom();
                shutdown = false;
                return '';
            }

            var preCreate = Date.now();
            stream = await createDom();

            var preShow = Date.now();
            if (label != '') {
                labelElement.innerHTML = label;
            }

            if (imgData != '') {
                var videoRect = video.getClientRects()[0];
                imgElement.style.top = videoRect.top + 'px';
                imgElement.style.left = videoRect.left + 'px';
                imgElement.style.width = videoRect.width + 'px';
                imgElement.style.height = videoRect.height + 'px';
                imgElement.src = imgData;
            }

            var preCapture = Date.now();
            var result = await new Promise(function (resolve, reject) {
                pendingResolve = resolve;
            });
            shutdown = false;

            return {
                'create': preShow - preCreate,
                'show': preCapture - preShow,
                'capture': Date.now() - preCapture,
                'img': result
            };
        }
    ''')

    display(js)


def video_frame(label, bbox):
    data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
    return data


# start streaming video from webcam
video_stream()
# label for video
label_html = 'Capturing...'
# initialize bounding box to empty
bbox = ''
count = 0
while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    img = js_to_image(js_reply['img'])

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480, 640, 4], dtype=np.uint8)

    # grayscale image for face detection
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # get face region coordinates
    faces = face_cascade.detectMultiScale(gray)
    # get face bounding box for overlay
    for (x, y, w, h) in faces:
        bbox_array = cv2.rectangle(bbox_array, (x, y), (x + w, y + h), (255, 0, 0), 2)

    bbox_array[:, :, 3] = (bbox_array.max(axis=2) > 0).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so the next frame gets a new overlay
    bbox = bbox_bytes
# Out:
# (480, 640)
# Saved to photo.jpg

# %%
# Load the face cascade classifier
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/haarcascades/haarcascade_frontalface_alt.xml')

# Load the input image
img = cv.imread('/content/drive/MyDrive/PCVK/facedet/mjordan.jpg')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# Detect faces in the image
faces = face_cascade.detectMultiScale(gray)

# Blur the detected faces
for (x, y, w, h) in faces:
    face_roi = gray[y:y+h, x:x+w]
    blurred_face_roi = cv.medianBlur(face_roi, 15)
    gray[y:y+h, x:x+w] = blurred_face_roi

# Display the result
plt.imshow(cv.cvtColor(gray, cv.COLOR_BGR2RGB))
plt.show()
